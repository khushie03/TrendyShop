# %% [markdown]
# ROADMAP
# Serpapi (videos) -> Frames mein divide krke -> Downloading video with the help of Youtubedl -> Yolo(Object Detection) -> Google lens par jakar (product search)
# or similarity search  : "This is when transcription of the videos is not available
# "Otherwise" :
# Search for the products directly through the api help .

# %%
from serpapi import GoogleSearch

params = {
  "engine": "youtube",
  "search_query": "trending indian brands lipstick ",
  "api_key": "c8b912a9727723424bffac813a03eb897d43cee8cfac0741c3b266a6cb8bef71"
}

search = GoogleSearch(params)
results = search.get_dict()
results
# Out:
# {'search_metadata': {'id': '669563f17d171a0928f550ec',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/991e0f1c31b0b1db/669563f17d171a0928f550ec.json',
#   'created_at': '2024-07-15 18:01:21 UTC',
#   'processed_at': '2024-07-15 18:01:21 UTC',
#   'youtube_url': 'https://www.youtube.com/results?search_query=trending+indian+brands+lipstick+',
#   'raw_html_file': 'https://serpapi.com/searches/991e0f1c31b0b1db/669563f17d171a0928f550ec.html',
#   'total_time_taken': 1.62},
#  'search_parameters': {'engine': 'youtube',
#   'search_query': 'trending indian brands lipstick '},
#  'search_information': {'total_results': 3887707,
#   'video_results_state': 'Results for exact spelling'},
#  'shorts_results': [{'position_on_page': 1,
#    'shorts': [{'title': 'Magic lipstick colour!?',
#      'link': 'https://www.youtube.com/shorts/Sgq97Hmt5n0',
#      'thumbnail': 'https://i.ytimg.com/vi/Sgq97Hmt5n0/hq720.jpg',
#      'views_original': '27M views',
#      'views': 27000000,
#      'video_id': 'Sgq97Hmt5n0'},
#     {'title': 'ASOKA MAKEUP 🇮🇳🇧🇷 0-100? 🔥 #asokamakeup #camilapudim #india #indian #indiamakeup #makeup',
#      'link': 'https://www.youtube.com/shorts/eueebphyAP8',
#      'thumbnail': 'https://i.ytimg.com/vi/eueebphyAP8/oardefault.jpg',
#      'views_original': '20M views',
#      'views': 20000000,
#      'video_id': 'eueebphyAP8'},
#     {'title': 'I Melted Every Clear Lipstick Together 💄',
#      'link': 'https://www.youtube.com/shorts/WzBBybaaK04',
#      'thumbnail': 'https://i.ytimg.com/vi/WzBBybaaK04/hq720.jpg',
#      'views_original': '80M views',
#      'views': 80000000,
#      'video_id': 'WzBBybaaK04'},
#     {'title': 'MOST POPULAR LIPSTICK BRANDS IN INDIA #bts #lipstick #lipsticklover #lips #lipgloss #top #japan',
#      'link': 'https://www.youtube.com/shorts/Ro2xqRJhdiw',
#      'thumbnail': 'https://i.ytimg.com/vi/Ro2xqRJhdiw/oar2.jpg',
#      'views_original': '100 views',
#      'views': 100,
#      'video_id': 'Ro2xqRJhdiw'},
#     {'title': 'Everyday Lipsticks for Indian skin',
#      'link': 'https://www.youtube.com/shorts/GWHeJ5OEs-0',
#      'thumbnail': 'https://i.ytimg.com/vi/GWHeJ5OEs-0/oar2.jpg',
#      'views_original': '1M views',
#      'views': 1000000,
#      'video_id': 'GWHeJ5OEs-0'},
#     {'title': '#shorts Jhanvi Kapoor 3 favourite product on Nykaa😍 #janvikapoor #naykaa #youtubeshorts #viral #yt',
#      'link': 'https://www.youtube.com/shorts/HoqSW_F-NC0',
#      'thumbnail': 'https://i.ytimg.com/vi/HoqSW_F-NC0/hq720.jpg',
#      'views_original': '1.9M views',
#      'views': 1900000,
#      'video_id': 'HoqSW_F-NC0'},
#     {'title': 'DONT TAP YOU LIP TINT PLS 😡#makeup #lipstick #makeuptutorial',
#      'link': 'https://www.youtube.com/shorts/yjvjsYRFkqA',
#      'thumbnail': 'https://i.ytimg.com/vi/yjvjsYRFkqA/oar2.jpg',
#      'views_original': '53M views',
#      'views': 53000000,
#      'video_id': 'yjvjsYRFkqA'},
#     {'title': 'Trying the same lipsticks on diffrent skin tones!! #ytshorts #makeup #beauty #lipstick',
#      'link': 'https://www.youtube.com/shorts/YYz1wpty0xg',
#      'thumbnail': 'https://i.ytimg.com/vi/YYz1wpty0xg/oar2.jpg',
#      'views_original': '25M views',
#      'views': 25000000,
#      'video_id': 'YYz1wpty0xg'},
#     {'title': "Sonam Kapoor's Lip Balm Beauty Hack",
#      'link': 'https://www.youtube.com/shorts/vD-ESlphowE',
#      'thumbnail': 'https://i.ytimg.com/vi/vD-ESlphowE/oar2.jpg',
#      'views_original': '5.3M views',
#      'views': 5300000,
#      'video_id': 'vD-ESlphowE'},
#     {'title': 'Lipstick Shades As Per Your Natural Lip Colour!!! 💄👌❤️',
#      'link': 'https://www.youtube.com/shorts/dl9le2qPnYY',
#      'thumbnail': 'https://i.ytimg.com/vi_webp/dl9le2qPnYY/oar2.webp',
#      'views_original': '631K views',
#      'views': 631000,
#      'video_id': 'dl9le2qPnYY'},
#     {'title': '#shorts Repairing New Lipstick Lipsticks#cosmeticrepair#satisfying#asmr#oddly#bts#fyp#viral#trend',
#      'link': 'https://www.youtube.com/shorts/VkQIXOLognU',
#      'thumbnail': 'https://i.ytimg.com/vi/VkQIXOLognU/oar2.jpg',
#      'views_original': '12M views',
#      'views': 12000000,
#      'video_id': 'VkQIXOLognU'},
#     {'title': 'RED LIPSTICKS ACCORDING TO SKIN TONE #redlipstick #lipstickswatch',
#      'link': 'https://www.youtube.com/shorts/0mKpn6ikqKE',
#      'thumbnail': 'https://i.ytimg.com/vi/0mKpn6ikqKE/oar2.jpg',
#      'views_original': '1.8M views',
#      'views': 1800000,
#      'video_id': '0mKpn6ikqKE'},
#     {'title': 'BEST LIP COMBO FOR DUSKY SKIN #makeup #lipstick #swatches #viral #trending #shorts #duskyskin',
#      'link': 'https://www.youtube.com/shorts/_-o1upKsXi0',
#      'thumbnail': 'https://i.ytimg.com/vi/_-o1upKsXi0/oardefault.jpg',
#      'views_original': '656K views',
#      'views': 656000,
#      'video_id': '_-o1upKsXi0'},
#     {'title': 'beautiful lipstick shades with shades name ❤️',
#      'link': 'https://www.youtube.com/shorts/JpA7ICY1rWs',
#      'thumbnail': 'https://i.ytimg.com/vi/JpA7ICY1rWs/oar2.jpg',
#      'views_original': '709K views',
#      'views': 709000,
#      'video_id': 'JpA7ICY1rWs'},
#     {'title': 'Lipsticks for Indian Skin Tones | Best Lipstick Shades for Indian Skin #ashortaday #shorts #lipstick',
#      'link': 'https://www.youtube.com/shorts/OMii3kJK63I',
#     {'title': 'Trying the same lipsticks on diffrent skin tones!! #ytshorts #makeup #beauty #lipstick',
#      'link': 'https://www.youtube.com/shorts/YYz1wpty0xg',
#      'thumbnail': 'https://i.ytimg.com/vi/YYz1wpty0xg/oar2.jpg',
#      'views_original': '25M views',
#      'views': 25000000,
#      'video_id': 'YYz1wpty0xg'},
#     {'title': "Sonam Kapoor's Lip Balm Beauty Hack",
#      'link': 'https://www.youtube.com/shorts/vD-ESlphowE',
#      'thumbnail': 'https://i.ytimg.com/vi/vD-ESlphowE/oar2.jpg',
#      'views_original': '5.3M views',
#      'views': 5300000,
#      'video_id': 'vD-ESlphowE'},
#     {'title': 'Lipstick Shades As Per Your Natural Lip Colour!!! 💄👌❤️',
#      'link': 'https://www.youtube.com/shorts/dl9le2qPnYY',
#      'thumbnail': 'https://i.ytimg.com/vi_webp/dl9le2qPnYY/oar2.webp',
#      'views_original': '631K views',
#      'views': 631000,
#      'video_id': 'dl9le2qPnYY'},
#     {'title': '#shorts Repairing New Lipstick Lipsticks#cosmeticrepair#satisfying#asmr#oddly#bts#fyp#viral#trend',
#      'link': 'https://www.youtube.com/shorts/VkQIXOLognU',
#      'thumbnail': 'https://i.ytimg.com/vi/VkQIXOLognU/oar2.jpg',
#      'views_original': '12M views',
#      'views': 12000000,
#      'video_id': 'VkQIXOLognU'},
#     {'title': 'RED LIPSTICKS ACCORDING TO SKIN TONE #redlipstick #lipstickswatch',
#      'link': 'https://www.youtube.com/shorts/0mKpn6ikqKE',
#      'thumbnail': 'https://i.ytimg.com/vi/0mKpn6ikqKE/oar2.jpg',
#      'views_original': '1.8M views',
#      'views': 1800000,
#      'video_id': '0mKpn6ikqKE'},
#     {'title': 'BEST LIP COMBO FOR DUSKY SKIN #makeup #lipstick #swatches #viral #trending #shorts #duskyskin',
#      'link': 'https://www.youtube.com/shorts/_-o1upKsXi0',
#      'thumbnail': 'https://i.ytimg.com/vi/_-o1upKsXi0/oardefault.jpg',
#      'views_original': '656K views',
#      'views': 656000,
#      'video_id': '_-o1upKsXi0'},
#     {'title': 'beautiful lipstick shades with shades name ❤️',
#      'link': 'https://www.youtube.com/shorts/JpA7ICY1rWs',
#      'thumbnail': 'https://i.ytimg.com/vi/JpA7ICY1rWs/oar2.jpg',
#      'views_original': '709K views',
#      'views': 709000,
#      'video_id': 'JpA7ICY1rWs'},
#     {'title': 'Lipsticks for Indian Skin Tones | Best Lipstick Shades for Indian Skin #ashortaday #shorts #lipstick',
#      'link': 'https://www.youtube.com/shorts/OMii3kJK63I',
#      'thumbnail': 'https://i.ytimg.com/vi/OMii3kJK63I/hq720.jpg',
#      'views_original': '703K views',
#      'views': 703000,
#      'video_id': 'OMii3kJK63I'}]}],
#  'video_results': [{'position_on_page': 2,
#    'title': 'My 3 Current Favorite Nude Lipsticks Ft. Pranali Mistry | #Shorts - Myntra',
#    'link': 'https://www.youtube.com/watch?v=zSpWVa3IkkY',
#    'serpapi_link': 'https://serpapi.com/search.json?engine=youtube_video&v=zSpWVa3IkkY',
#    'channel': {'name': 'Myntra',
#     'link': 'https://www.youtube.com/@myntra',
#     'verified': True,
#     'thumbnail': 'https://yt3.ggpht.com
AE%253D',
#     'thumbnail': 'https://i.ytimg.com/vi/B176SG0i4I8/mqdefault.jpg'},
#    {'query': 'glossy lipstick',
#     'link': 'https://www.youtube.com/results?search_query=glossy+lipstick&sp=eAE%253D',
#     'thumbnail': 'https://i.ytimg.com/vi/AJgzoldA04M/mqdefault.jpg'},
#    {'query': 'lipstick haul',
#     'link': 'https://www.youtube.com/results?search_query=lipstick+haul&sp=eAE%253D',
#     'thumbnail': 'https://i.ytimg.com/vi/978eJi0XGAw/mqdefault.jpg'},
#    {'query': 'best lipstick long-lasting',
#     'link': 'https://www.youtube.com/results?search_query=best+lipstick+long-lasting&sp=eAE%253D',
#     'thumbnail': 'https://i.ytimg.com/vi/j1qHc-ZG0pU/mqdefault.jpg'},
#    {'query': 'lipstick colour name',
#     'link': 'https://www.youtube.com/results?search_query=lipstick+colour+name&sp=eAE%253D',
#     'thumbnail': 'https://i.ytimg.com/vi/rxsFBu0ZzAA/mqdefault.jpg'}]},
#  'pagination': {'current': 'https://www.youtube.com/results?search_query=trending+indian+brands+lipstick+',
#   'next': 'https://www.youtube.com/results?search_query=trending%20indian%20brands%20lipstick%20&sp=%253D%253D',
#   'next_page_token': '%3D%3D'},
#  'serpapi_pagination': {'current': 'https://serpapi.com/search.json?engine=youtube&search_query=trending+indian+brands+lipstick+',
#   'next': 'https://serpapi.com/search.json?engine=youtube&search_query=trending+indian+brands+lipstick+&sp=%253D%253D',
#   'next_page_token': '%3D%3D'}}

# %%
from serpapi import GoogleSearch
from youtube_transcript_api import YouTubeTranscriptApi, NoTranscriptAvailable
import google.generativeai as genai

genai.configure(api_key="AIzaSyDM9xdKD9JDW_wu6Lp1gnCraUK3Ds-DPNc")
def trend_search(product_name):
    params = {
        "engine": "youtube",
        "search_query": product_name,
        "api_key": "c8b912a9727723424bffac813a03eb897d43cee8cfac0741c3b266a6cb8bef71",

    }
    search = GoogleSearch(params)
    results = search.get_dict()
    shorts_results = results["shorts_results"]
    links = []
    for result in shorts_results:
        links.extend(short['link'] for short in result['shorts'])
    def transcript_products(youtube_video_url):
        try:
            if "=" in youtube_video_url:
                video_id = youtube_video_url.split("=")[1]
                transcript_text = YouTubeTranscriptApi.get_transcript(video_id)

                transcript = ""
                for i in transcript_text:
                    transcript += " " + i["text"]

                return transcript
            else:
                return "Invalid YouTube URL format"
        
        except NoTranscriptAvailable:
            return "No transcription available"
        except Exception as e:
            raise e
    def generate_gemini_content(transcript_text):
        prompt = """
        Here I am trying to analyse the trends through the trending videos and accordingly generating a list of the products.
        Here you have given the transcripts of the trending youtube videos and you have to generate a list of the
        products that are mentioned in that transcripts .Here automated trend extractor is there which will automatically extract the products 
        related to the videos .
        """

        model = genai.GenerativeModel("gemini-pro")
        response = model.generate_content(prompt + transcript_text)
        return response.text
    for i in links[:5]:
        script = transcript_products(i)
        x = generate_gemini_content(script)
        print(x)
trend_search("latest trendy lipsticks")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 52
#      50         x = generate_gemini_content(script)
#      51         print(x)
# ---> 52 trend_search("latest trendy lipsticks")
#
# Cell In[26], line 50, in trend_search(product_name)
#      48 for i in links[:5]:
#      49     script = transcript_products(i)
# ---> 50     x = generate_gemini_content(script)
#      51     print(x)
#
# Cell In[26], line 46, in trend_search.<locals>.generate_gemini_content(transcript_text)
#      38 prompt = """
#      39 Here I am trying to analyse the trends through the trending videos and accordingly generating a list of the products.
#      40 Here you have given the transcripts of the trending youtube videos and you have to generate a list of the
#      41 products that are mentioned in that transcripts .Here automated trend extractor is there which will automatically extract the products
#      42 related to the videos .
#      43 """
#      45 model = genai.GenerativeModel("gemini-pro")
# ---> 46 response = model.generate_content(prompt + transcript_text)
#      47 return response.text
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\generativeai\generative_models.py:262, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     260         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     261     else:
# --> 262         response = self._client.generate_content(
#     263             request,
#     264             **request_options,
#     265         )
#     266         return generation_types.GenerateContentResponse.from_response(response)
#     267 except google.api_core.exceptions.InvalidArgument as e:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:812, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     809 self._validate_universe_domain()
#     811 # Send the request.
# --> 812 response = rpc(
#     813     request,
#     814     retry=retry,
#     815     timeout=timeout,
#     816     metadata=metadata,
#     817 )
#     819 # Done; return the response.
#     820 return response
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\grpc\_channel.py:1173, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1161 def __call__(
#    1162     self,
#    1163     request: Any,
#    (...)
#    1168     compression: Optional[grpc.Compression] = None,
#    1169 ) -> Any:
#    1170     (
#    1171         state,
#    1172         call,
# -> 1173     ) = self._blocking(
#    1174         request, timeout, metadata, credentials, wait_for_ready, compression
#    1175     )
#    1176     return _end_unary_response_blocking(state, call, False, None)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\grpc\_channel.py:1157, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1141 state.target = _common.decode(self._target)
#    1142 call = self._channel.segregated_call(
#    1143     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1144     self._method,
#    (...)
#    1155     self._context,
#    1156 )
# -> 1157 event = call.next_event()
#    1158 _handle_event(event, state, self._response_deserializer)
#    1159 return state, call
#
# File src\python\grpcio\grpc\_cython\_cygrpc/channel.pyx.pxi:367, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src\python\grpcio\grpc\_cython\_cygrpc/channel.pyx.pxi:188, in grpc._cython.cygrpc._next_call_event()
#
# File src\python\grpcio\grpc\_cython\_cygrpc/channel.pyx.pxi:182, in grpc._cython.cygrpc._next_call_event()
#
# File src\python\grpcio\grpc\_cython\_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src\python\grpcio\grpc\_cython\_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._internal_latent_event()
#
# File src\python\grpcio\grpc\_cython\_cygrpc/completion_queue.pyx.pxi:42, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:

# %%
from serpapi import GoogleSearch
from youtube_transcript_api import YouTubeTranscriptApi, NoTranscriptAvailable
import google.generativeai as genai

# Configure the Gemini API
genai.configure(api_key="YOUR_GEMINI_API_KEY")

def trend_search(product_name):
    # Step 1: Extract links of related videos
    params = {
        "engine": "youtube",
        "search_query": product_name,
        "api_key": "YOUR_SERPAPI_KEY"
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    shorts_results = results.get("shorts_results", [])
    links = [short['link'] for result in shorts_results for short in result['shorts']]

    def transcript_products(youtube_video_url):
        # Step 2: Get transcripts of these videos
        try:
            video_id = youtube_video_url.split("=")[1] if "=" in youtube_video_url else None
            if not video_id:
                return "Invalid YouTube URL format"

            transcript_text = YouTubeTranscriptApi.get_transcript(video_id)
            transcript = " ".join([i["text"] for i in transcript_text])
            return transcript
        
        except NoTranscriptAvailable:
            return "No transcription available"
        except Exception as e:
            raise e

    def generate_gemini_content(transcript_text):
        # Step 3: Generate product lists from transcripts using Gemini
        prompt = """
        Here I am trying to analyse the trends through the trending videos and accordingly generating a list of the products.
        Here you have given the transcripts of the trending youtube videos and you have to generate a list of the
        products that are mentioned in that transcripts. Here automated trend extractor is there which will automatically extract the products 
        related to the videos.
        """

        model = genai.GenerativeModel("gemini-pro")
        response = model.generate_content(prompt + transcript_text)
        return response.text

    for link in links:
        script = transcript_products(link)
        if script not in ["Invalid YouTube URL format", "No transcription available"]:
            product_list = generate_gemini_content(script)
            print(product_list)

# %%
x = trend_search("trending lipstick products")

# %%
print(x)
# Out:
# None

# %%
from serpapi import GoogleSearch
from youtube_transcript_api import YouTubeTranscriptApi, NoTranscriptAvailable , TranscriptsDisabled
import google.generativeai as genai

genai.configure(api_key="AIzaSyDM9xdKD9JDW_wu6Lp1gnCraUK3Ds-DPNc")
def trend_search(product_name):
    def link_extraction(product_name):
        params = {
        "engine": "youtube",
        "search_query": product_name,
        "api_key": "c8b912a9727723424bffac813a03eb897d43cee8cfac0741c3b266a6cb8bef71",}
        search = GoogleSearch(params)
        results = search.get_dict()
        shorts_results = results["shorts_results"]
        return shorts_results
    
    def get_video_id_from_url(youtube_video_url):
        if "watch?v=" in youtube_video_url:
            return youtube_video_url.split("watch?v=")[1]
        elif "shorts/" in youtube_video_url:
            return youtube_video_url.split("shorts/")[1]
        else:
            return None

    def transcript_products(youtube_video_url):
        try:
            video_id = get_video_id_from_url(youtube_video_url)
            if video_id:
                transcript_text = YouTubeTranscriptApi.get_transcript(video_id)
                transcript = " ".join([item['text'] for item in transcript_text])
                return transcript
            else:
                return "Invalid YouTube URL format"
        except TranscriptsDisabled:
            return "Transcripts are disabled for this video"
        except NoTranscriptAvailable:
            return "No transcription available"
        except Exception as e:
            raise e
    def generate_gemini_content(transcript_text):
        prompt = """
        Here I am trying to analyse the trends through the trending videos and accordingly generating a list of the products.
        Here you have given the transcripts of the trending youtube videos and you have to generate a list of the
        products that are mentioned in that transcripts .Here automated trend extractor is there which will automatically extract the products 
        related to the videos .
        """

        model = genai.GenerativeModel("gemini-pro")
        response = model.generate_content(prompt + transcript_text)
        return response.text
    shorts_results = link_extraction(product_name)
    links = []
    thumbnail = []
    for result in shorts_results:
        links.extend(short['link'] for short in result['shorts'])
    for result in shorts_results:
        links.extend(short['thumbnail'] for short in result['shorts'])
    
    print("The links generated :",links)
    print("List of the image link",thumbnail)
    products = []
    for i in links[:10]:
        script = transcript_products(i)
        print(script)
        x = generate_gemini_content(script)
        products.append(x)
    print(products)
trend_search("trending lipstick products")
# Out:
c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\youtube_transcript_api\_api.py:137 in get_transcript
#     return cls.list_transcripts(video_id, proxies, cookies).find_transcript(languages).fetch(preserve_formatting=preserve_formatting)
#
#   File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\youtube_transcript_api\_transcripts.py:292 in fetch
#     return _TranscriptParser(preserve_formatting=preserve_formatting).parse(
#
#   File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\youtube_transcript_api\_transcripts.py:358 in parse
#     for xml_element in ElementTree.fromstring(plain_data)
#
#   File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\xml\etree\ElementTree.py:1336 in XML
#     return parser.close()
#
#   File <string>
# ParseError: no element found: line 1, column 0

# %%
from serpapi import GoogleSearch

params = {
  "engine": "youtube",
  "search_query": "trendy lipstick products india",
  "api_key": "c8b912a9727723424bffac813a03eb897d43cee8cfac0741c3b266a6cb8bef71"
}

search = GoogleSearch(params)
results = search.get_dict()
video_results = results["video_results"]

# %%
video_results
# Out:
# [{'position_on_page': 3,
#   'title': 'This is why you need a lipstick that’s YOUR lip shade',
#   'link': 'https://www.youtube.com/watch?v=jOEv-FjdPlU',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=youtube_video&v=jOEv-FjdPlU',
#   'channel': {'name': 'Christxiee',
#    'link': 'https://www.youtube.com/@christxiee',
#    'thumbnail': 'https://yt3.ggpht.com/dWaJx-iyVNEW6I5WcqFKHsvcot7Qdu2Mp9bAP9bUaGPQXuYJLXaaLGmSMAG6rSKWNaflhUEinQ=s68-c-k-c0x00ffffff-no-rj'},
#   'published_date': '2 years ago',
#   'views': 1847536,
#   'length': '0:20',
#   'description': "So i'm gonna try this again without applying my lip balm i'll do it but look at my lips are so dried i'll wipe off my lip balm though try\xa0...",
#   'thumbnail': {'static': 'https://i.ytimg.com/vi/jOEv-FjdPlU/hq720_2.jpg?sqp=-oaymwE2COgCEMoBSFXyq4qpAygIARUAAIhCGABwAcABBvABAfgBzgWAAoAKigIMCAAQARhlIFMoTzAP&rs=AOn4CLCABQTzavR-Fgng3heLwBC2B0m5kw',
#    'rich': 'https://i.ytimg.com/an_webp/jOEv-FjdPlU/mqdefault_6s.webp?du=3000&sqp=CNfk7rQG&rs=AOn4CLA39-_QZ-P-rCUQ2nkSWsk4qSGlFw'}},
#  {'position_on_page': 4,
#   'title': 'BEST LIPSTICKS For INDIAN SKINTONE! | TheSassThing',
#   'link': 'https://www.youtube.com/watch?v=YcFgmm_yL98',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=youtube_video&v=YcFgmm_yL98',
#   'channel': {'name': 'Michu',
#    'link': 'https://www.youtube.com/@MichuYoutube',
#    'verified': True,
#    'thumbnail': 'https://yt3.ggpht.com/ytc/AIdro_nMqapH8zyknUKf9QmM1lvok1plhIhDEf3Lr9Dap6Rnxw=s68-c-k-c0x00ffffff-no-rj'},
#   'published_date': '4 years ago',
#   'views': 609836,
#   'length': '8:37',
#   'description': 'Shot this video in natural lighting to show you guys the real shades of the lipsticks :) My Shade: Mac NC37 Products used: Nude\xa0...',
#   'thumbnail': {'static': 'https://i.ytimg.com/vi/YcFgmm_yL98/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDjV1Wav_Lj3gK1qAcvZS4XS3O63A',
#    'rich': 'https://i.ytimg.com/an_webp/YcFgmm_yL98/mqdefault_6s.webp?du=3000&sqp=CNz87rQG&rs=AOn4CLDTNWp7-G3O-GpcWmAOd9ELzcU2sg'}},
#  {'position_on_page': 6,
#   'title': 'Lip Glosses I am obsessed with | Affordable starting Rs.150/-',
#   'link': 'https://www.youtube.com/watch?v=lVj4IaFCLjY',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=youtube_video&v=lVj4IaFCLjY',
#   'channel': {'name': 'Prakriti Singh',
#    'link': 'https://www.youtube.com/@PrakritiSingh',
#    'verified': True,
#    'thumbnail': 'https://yt3.ggpht.com/0B8B0d-2z_2KSWgjotH-vXUkbmjts4hm6PGujKqCwwSKd4vWMI1W7-GugIGkFZFFoKBY0sZmEQ=s68-c-k-c0x00ffffff-no-rj'},
#   'published_date': '1 year ago',
#   'views': 586035,
#   'length': '6:01',
#   'description': 'Products mentioned in the video: Swiss Beauty Lip Gloss - Gloss Me\xa0...',
#   'extensions': ['4K'],
#   'thumbnail': {'static': 'https://i.ytimg.com/vi/lVj4IaFCLjY/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAtht7q3M-VERY6oHkEzr8dk1UNzw',
#    'rich': 'https://i.ytimg.com/an_webp/lVj4IaFCLjY/mqdefault_6s.webp?du=3000&sqp=CMLl7rQG&rs=AOn4CLA5KawzIWkaPfiCcLYYx2WzqaKlBA'}},
#  {'position_on_page': 7,
#   'title': 'Alia Bhatt "weird" lipstick hack😂🥴Yay or Nay? #ashortaday #lipstick #hack',
#   'link': 'https://www.youtube.com/watch?v=syPi-WOkesU',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=youtube_video&v=syPi-WOkesU',
#   'channel': {'name': 'Himadri Patel',
#    'link': 'https://www.youtube.com/@HimadriPatel',
#    'verified': True,
#    'thumbnail': 'https://yt3.ggpht.com/ytc/AIdro_nSgS7O6Xxl060jo6ChML7gdXJAWm-UmFe1GXsNTfai4OA=s68-c-k-c0x00ffffff-no-rj'},
#   'published_date': '10 months ago',
#   'views': 1609553,
#   'length': '0:58',
#   'description': "The way I apply my lipstick is not considered wait and apply the lipstick it's a bit weird apparently Alia Bhatt has her own weird way\xa0...",
#   'thumbnail': {'static': 'https://i.ytimg.com/vi/syPi-WOkesU/hq720.jpg?sqp=-oaymwE2COgCEMoBSFXyq4qpAygIARUAAIhCGABwAcABBvABAfgBtgiAAoAPigIMCAAQARhyIEgoOTAP&rs=AOn4CLD4SaHg0_M7i6aEh03VI2MXn0RxWA',
#    'rich': 'https://i.ytimg.com/an_webp/syPi-WOkesU/mqdefault_6s.webp?du=3000&sqp=CJL_7rQG&rs=AOn4CLAMmqzegfHRUlHdg1l3icuvN7ePBA'}},
#  {'position_on_page': 9,
#   'title': 'The ONLY Lip Gloss You Need #unsponsored #lipgloss #makeup',
#   'link': 'https://www.youtube.com/watch?v=leXyADcQ50I',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=youtube_video&v=leXyADcQ50I',
#   'channel': {'name': 'Chetali Chadha',
#    'link': 'https://www.youtube.com/@chetalia',
#    'verified': True,
#    'thumbnail': 'https://yt3.ggpht.com/ytc/AIdro_mUwCskPN_yMKI58Osq0hnW0aeA39NkOwVu9UmB7ezjCkM=s68-c-k-c0x00ffffff-no-rj'},
#   'published_date': '1 year ago',
#   'views': 722897,
#   'length': '0:16',
#   'description': "THANK YOU for the overwhelming response to my SKINCARE MASTERCLASS! It's heartwarming that hundreds of you already\xa0...",
#   'thumbnail': {'static': 'https://i.ytimg.com/vi/leXyADcQ50I/hq720.jpg?sqp=-oaymwE2COgCEMoBSFXyq4qpAygIARUAAIhCGABwAcABBvABAfgBtgiAAoAPigIMCAAQARhZIGUoWzAP&rs=AOn4CLDQFM8rZ7lL8bG-nzOyP1SDiLfFEg',
#    'rich': 'https://i.ytimg.com/an_webp/leXyADcQ50I/mqdefault_6s.webp?du=3000&sqp=CJzg7rQG&rs=AOn4CLDEGq0NWOtt588Fon_Ce8C-lRr-XQ'}},
#  {'position_on_page': 10,
#   'title': '8 Lipstick Hacks Every Girl Should Know ||Beauty Hacks',
#   'link': 'https://www.youtube.com/watch?v=VhR-5YqxbWQ',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=youtube_video&v=VhR-5YqxbWQ',
#   'channel': {'name': 'Rohit Sachdeva',
#    'link': 'https://www.youtube.com/@rohitsachdeva',
#    'verified': True,
#    'thumbnail': 'https://yt3.ggpht.com/4769Fd6XDrj8PIo8OlOp1BQN735hqqS_v65MnnH9Rpgedr2TTsEdkcof2xihBRCUk_HuwnJj=s68-c-k-c0x00ffffff-no-rj'},
#   'published_date': '2 years ago',
#   'views': 2967962,
#   'length': '7:21',
#   'description': 'Lipstick is the most loved product in makeup. In this video we will talk about 8 Lipstick Hacks that every girl should know and they\xa0...',
#   'extensions': ['CC'],
#   'thumbnail': {'static': 'https://i.ytimg.com/vi/VhR-5YqxbWQ/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCoFtNn0c_P6_Obs8Axk2wRykcH2g',
#    'rich': 'https://i.ytimg.com/an_webp/VhR-5YqxbWQ/mqdefault_6s.webp?du=3000&sqp=COiF77QG&rs=AOn4CLAGxAbQ3BugAr7IC_w65kmACyIxBA'}},
#  {'position_on_page': 12,
#   'title': "Why that LIP COLOR doesn't look good on me? How to Choose Best LIP COLOUR for My SKIN TONE 💋💄",
#   'link': 'https://www.youtube.com/watch?v=jY2Kg9ZJGE0',
#   'serpapi_link': 'https://serpapi.com/search.json?engine=youtube_video&v=jY2Kg9ZJGE0',
#   'channel': {'name': 'dear peachie',
#    'link': 'https://www.youtube.com/@dearpeachie',
#    'thumbnail': 'https://yt3.ggpht.com/ytc/AIdro_kNiIne9SqTgUvtkkj5fYojgMXwWLZMRh6C0eXq-eKGhA=s68-c-k-c0x00ffffff-no-rj'},
#   'published_date': '2 years ago',
#   'views': 1438821,
#   'length': '12:33',
#   'description': 'Hello peachies🍑 There are literally hundreds of different lipsticks out there in varying tones and finishes, so finding one that you\xa0...',
#   'extensions': ['CC'],
#   'thumbnail': {'static': 'https://i.ytimg.com/vi/jY2Kg9ZJGE0/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDHhOiv-yCip404QvJImr2YUzqXNw',
#    'rich': 'https://i.ytimg.com/an_webp/jY2Kg9ZJGE0/mqdefault_6s.webp?du=3000&sqp=CJCG77QG&rs=AOn4CLAdf6_0dDsYGOx5gy6McwUnbniAOA'}}]

# %%
for video in video_results:
    print(video['link'])
# Out:
# https://www.youtube.com/watch?v=jOEv-FjdPlU
# https://www.youtube.com/watch?v=YcFgmm_yL98
# https://www.youtube.com/watch?v=lVj4IaFCLjY
# https://www.youtube.com/watch?v=syPi-WOkesU
# https://www.youtube.com/watch?v=leXyADcQ50I
# https://www.youtube.com/watch?v=VhR-5YqxbWQ
# https://www.youtube.com/watch?v=jY2Kg9ZJGE0

# %%
def transcript_products(youtube_video_url):
    if youtube_video_url:
                            transcript_text = YouTubeTranscriptApi.get_transcript(video_id)
                            transcript = " ".join([item['text'] for item in transcript_text])
                            return transcript
    else:
        return "Invalid YouTube URL format"
    except NoTranscriptAvailable:
                        return "No transcription available"
   except Exception as e:
                        return f"Error: {str(e)}"

# %%
from serpapi import GoogleSearch
from youtube_transcript_api import YouTubeTranscriptApi, NoTranscriptAvailable
import google.generativeai as genai

genai.configure(api_key="AIzaSyDM9xdKD9JDW_wu6Lp1gnCraUK3Ds-DPNc")

def trend_search(product_name):
    def link_extraction(product_name):
        params = {
            "engine": "youtube",
            "search_query": product_name,
            "api_key": "c8b912a9727723424bffac813a03eb897d43cee8cfac0741c3b266a6cb8bef71"
        }

        search = GoogleSearch(params)
        results = search.get_dict()
        video_results = results.get("video_results", [])
        return video_results

    def get_video_id_from_url(youtube_video_url):
        if "watch?v=" in youtube_video_url:
            return youtube_video_url.split("watch?v=")[1]
        elif "shorts/" in youtube_video_url:
            return youtube_video_url.split("shorts/")[1]
        else:
            return None

    from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

    def fetch_transcript(video_id):
        video_id = get_video_id_from_url(video_id)
        try:
            transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['en'])
            return transcript
        except (TranscriptsDisabled, NoTranscriptFound):
            try:
                # Attempt to fetch the transcript in any available language
                transcript = YouTubeTranscriptApi.get_transcript(video_id)
                return transcript
            except Exception as e:
                print(f"Error: Could not retrieve a transcript for the video {video_id}! {str(e)}")
                return None


    def generate_gemini_content(transcript_text):
        prompt = """
        Here I am trying to analyze the trends through the trending videos and accordingly generating a list of the products.
        Here you have given the transcripts of the trending YouTube videos and you have to generate a list of the
        products that are mentioned in that transcripts. Here automated trend extractor is there which will automatically extract the products 
        related to the videos.
        """

        try:
            response = genai.generate(
                model="text-bison-001",
                messages=[{"role": "system", "content": prompt + transcript_text}]
            )
            return response['choices'][0]['message']['content']
        except Exception as e:
            return f"Error: {str(e)}"

    video_results = link_extraction(product_name)
    links = []
    thumbnails = []
    
    for video in video_results:
        links.append(video['link'])
        thumbnails.append(video['thumbnail'])
        print(video['link'])
        print(video['thumbnail'])
    
    print("The links generated:", links)
    print("List of the image link", thumbnails)

    products = []
    for link in links:
        script = fetch_transcript(link)
        #print(script)
        if "Error" not in script:
            product_list = generate_gemini_content(script)
            products.append(product_list)
        else:
            products.append(script)

    print(products)

trend_search("trending lipstick products India")
# Out:
# https://www.youtube.com/watch?v=SrfvgMH1NmY
# {'static': 'https://i.ytimg.com/vi/SrfvgMH1NmY/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCmQRTmqh9swe61GLdNa6_oLPg3rQ', 'rich': 'https://i.ytimg.com/an_webp/SrfvgMH1NmY/mqdefault_6s.webp?du=3000&sqp=CI6m77QG&rs=AOn4CLD8bBeTmuzGWvUBs32vYwAAyThubg'}
# https://www.youtube.com/watch?v=VgGlvxJeqJg
# {'static': 'https://i.ytimg.com/vi/VgGlvxJeqJg/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDFKYL38NDEPFtukrD77wGHd6ViWw', 'rich': 'https://i.ytimg.com/an_webp/VgGlvxJeqJg/mqdefault_6s.webp?du=3000&sqp=CKiG77QG&rs=AOn4CLD0j_MmRpzrxfae0VM8rgIoReaFjA'}
# https://www.youtube.com/watch?v=L3mcbH2jPRk
# {'static': 'https://i.ytimg.com/vi/L3mcbH2jPRk/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4C
auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - ne ("Nepali")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - or ("Odia")
#  - om ("Oromo")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - ti ("Tigrinya")
#  - ts ("Tsonga")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - vi ("Vietnamese")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 87
#      83             products.append(script)
#      85     print(products)
# ---> 87 trend_search("trending lipstick products India")
#
# Cell In[14], line 79, in trend_search(product_name)
#      77 script = fetch_transcript(link)
#      78 #print(script)
# ---> 79 if "Error" not in script:
#      80     product_list = generate_gemini_content(script)
#      81     products.append(product_list)
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
youtube_video_url = 'https://www.youtube.com/watch?v=jOEv-FjdPlU'
if "watch?v=" in youtube_video_url:
        video_id = youtube_video_url.split("watch?v=")[1]
transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['en'])

# %%
from serpapi import GoogleSearch
from youtube_transcript_api import YouTubeTranscriptApi, NoTranscriptAvailable
import google.generativeai as genai
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

genai.configure(api_key="AIzaSyDM9xdKD9JDW_wu6Lp1gnCraUK3Ds-DPNc")

def trend_search(product_name):
    def link_extraction(product_name):
        params = {
            "engine": "youtube",
            "search_query": product_name,
            "api_key": "c8b912a9727723424bffac813a03eb897d43cee8cfac0741c3b266a6cb8bef71"
        }

        search = GoogleSearch(params)
        results = search.get_dict()
        video_results = results.get("video_results", [])
        return video_results

    def get_video_id_from_url(youtube_video_url):
        if "watch?v=" in youtube_video_url:
            return youtube_video_url.split("watch?v=")[1]
        elif "shorts/" in youtube_video_url:
            return youtube_video_url.split("shorts/")[1]
        else:
            return None

    

    def fetch_transcript(video_id):
        video_id = get_video_id_from_url(video_id)
        try:
            transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['en'])
            return transcript
        except (TranscriptsDisabled, NoTranscriptFound):
            try:
                # Attempt to fetch the transcript in any available language
                transcript = YouTubeTranscriptApi.get_transcript(video_id)
                return transcript
            except Exception as e:
                print(f"Error: Could not retrieve a transcript for the video {video_id}! {str(e)}")
                return None


    def generate_gemini_content(transcript_text):
        prompt = """
        Here I am trying to analyze the trends through the trending videos and accordingly generating a list of the products.
        Here you have given the transcripts of the trending YouTube videos and you have to generate a list of the
        products that are mentioned in that transcripts. Here automated trend extractor is there which will automatically extract the products 
        related to the videos.
        """

        try:
            response = genai.generate(
                model="text-bison-001",
                messages=[{"role": "system", "content": prompt + transcript_text}]
            )
            return response['choices'][0]['message']['content']
        except Exception as e:
            return f"Error: {str(e)}"

    video_results = link_extraction(product_name)
    links = []
    thumbnails = []
    
    for video in video_results:
        links.append(video['link'])
        thumbnails.append(video['thumbnail'])
        print(video['link'])
        print(video['thumbnail'])
    
    print("The links generated:", links)
    print("List of the image link", thumbnails)

    products = []
    for link in links:
        script = fetch_transcript(link)
        #print(script)
        if "Error" not in script:
            product_list = generate_gemini_content(script)
            products.append(product_list)
        else:
            products.append(script)

    print(products)

trend_search("trending lipstick products India")
# Out:
# https://www.youtube.com/watch?v=SrfvgMH1NmY
# {'static': 'https://i.ytimg.com/vi/SrfvgMH1NmY/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLB0QCW49cKCh0hEOGGmkNoAEQg9Ig'}
# https://www.youtube.com/watch?v=VgGlvxJeqJg
# {'static': 'https://i.ytimg.com/vi/VgGlvxJeqJg/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAdhZ9EsjQaieF1OK_YiCDu__efaA'}
# https://www.youtube.com/watch?v=sigVRlLzkFc
# {'static': 'https://i.ytimg.com/vi/sigVRlLzkFc/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBmklgAApWG8qQU848A7i89hGnvDw'}
# https://www.youtube.com/watch?v=wUBPHWGJO8Q
# {'static': 'https://i.ytimg.com/vi/wUBPHWGJO8Q/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CL
hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCvqTEyttfX-HqMDAA8q9bxl6E-Kg'}, {'static': 'https://i.ytimg.com/vi/hR7vajT9QCI/hq720.jpg?sqp=-oaymwE9COgCEMoBSFryq4qpAy8IARUAAAAAGAAlAADIQj0AgKJDeAHwAQH4AbYIgAKAD4oCDAgAEAEYfyBDKCgwDw==&rs=AOn4CLAzL8C_2RSnTGNvznJ2n4Nxiqeevw'}, {'static': 'https://i.ytimg.com/vi/Agka_pXNyG8/hqdefault.jpg?sqp=-oaymwEjCOADEI4CSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAiPeNWQlQfbt591vUG5S1xY9W0zA'}]
# Error: Could not retrieve a transcript for the video SrfvgMH1NmY!
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=SrfvgMH1NmY! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (SrfvgMH1NmY) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - hi ("Hindi (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - ne ("Nepali")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - or ("Odia")
#  - om ("Oromo")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - ti ("Tigrinya")
#  - ts ("Tsonga")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - vi ("Vietnamese")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 88
#      84             products.append(script)
#      86     print(products)
# ---> 88 trend_search("trending lipstick products India")
#
# Cell In[17], line 80, in trend_search(product_name)
#      78 script = fetch_transcript(link)
#      79 #print(script)
# ---> 80 if "Error" not in script:
#      81     product_list = generate_gemini_content(script)
#      82     products.append(product_list)
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
sorted(set(list("hello")))
# Out:
# ['e', 'h', 'l', 'o']

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_shopping",
  "q": "Rouge Volupté Shine Lipsticks",
  "api_key": "c8b912a9727723424bffac813a03eb897d43cee8cfac0741c3b266a6cb8bef71"
}

search = GoogleSearch(params)
results = search.get_dict()
shopping_results = results["shopping_results"]

# %%
arr = [1 , 2 , 3]
arr1 = [ 2 , 4 , 6]
arr + arr1[: : -1]
# Out:
# [1, 2, 3, 6, 4, 2]

# %%
nums = [ 4 , 4 , 4 , 4]
len(set(nums))
#set(nums) * len(nums)
for i in set(nums):
    print(i)
# Out:
# 4

# %%
import numpy as np
for i in
# Out:
# array({4}, dtype=object)

# %%
shopping_results
# Out:
# [{'position': 1,
#   'title': 'Yves Saint Laurent Beaute Rouge Volupte Shine Lipstick',
#   'link': 'https://www.amazon.com/Yves-Saint-Laurent-Lipstick-Incandescent/dp/B00AYCOT3I?source=ps-sl-shoppingads-lpcontext&ref_=fplfs&psc=1&smid=A2I0WI5DHMAWB9',
#   'product_link': 'https://www.google.com/shopping/product/11231527812689993481?gl=us',
#   'product_id': '11231527812689993481',
#   'serpapi_product_api': 'https://serpapi.com/search.json?device=desktop&engine=google_product&gl=us&google_domain=google.com&hl=en&product_id=11231527812689993481',
#   'number_of_comparisons': '5+',
#   'comparison_link': 'https://www.google.com/shopping/product/11231527812689993481/offers?udm=28&q=Rouge+Volupt%C3%A9+Shine+Lipsticks&hl=en&gl=us&prds=eto:6779790499336198549_0,pid:12054120350257406093,rsk:PC_11031005702094840638&sa=X&ved=0ahUKEwj-jfjtidKHAxUhqZUCHfPuF-8Q3q4ECJgM',
#   'serpapi_product_api_comparisons': 'https://serpapi.com/search.json?engine=google_product&filter=eto%3A6779790499336198549_0%2Cpid%3A12054120350257406093%2Crsk%3APC_11031005702094840638&gl=us&hl=en&offers=1&product_id=11231527812689993481&sa=X&ved=0ahUKEwj-jfjtidKHAxUhqZUCHfPuF-8Q3q4ECJgM',
#   'source': 'Amazon.com - Seller',
#   'price': '$56.00',
#   'extracted_price': 56.0,
#   'rating': 4.6,
#   'reviews': 20710,
#   'thumbnail': 'https://encrypted-tbn3.gstatic.com/shopping?q=tbn:ANd9GcQviGQaApgs3X43pzkD_smwry0tFrzS7hm4lPM2opFlF-FP9UKrkyz-MHQy9Q6LvRbJn5YMvFn8Uql71693cdVVwN2yG2YgZqv8wAnNHjbTScRm6mHjvJPC&usqp=CAE',
#   'delivery': 'Free delivery'},
#  {'position': 2,
#   'title': 'Yves Saint Laurent Rouge Volupte Sh

#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcQB4NWJijqO2RjRVnXi0UzG70q2IO8StEh3VvQMjKzhSr8mQfkJV8G-8juEbeGrAZcun_bkso5oSPi7uUAWbNjlVAR-dopEFbAHF1a8Fu0PhL6DCMmRX8FNvg&usqp=CAE',
#   'delivery': '$30.00 delivery'},
#  {'position': 49,
#   'title': 'YSL Rouge Volupté Candy Glaze Lipstick, 5',
#   'link': 'https://mcgrocer.com/products/ysl-rouge-volupte-candy-glaze-lipstick?currency=GBP&variant=45510473351406&utm_source=google&utm_medium=cpc&utm_campaign=Google+Shopping&stkn=9bdd4526a2c2&srsltid=AfmBOorFWCCrph4vW0KGjQvRJuG7WIhVSRByPIZm3xTTsx-SPKQasXK7aCw&com_cvv=d30042528f072ba8a22b19c81250437cd47a2f30330f0ed03551c4efdaf3409e',
#   'product_link': 'https://www.google.com/shopping/product/1?gl=us&prds=pid:9670509099135886512',
#   'product_id': '9670509099135886512',
#   'serpapi_product_api': 'https://serpapi.com/search.json?device=desktop&engine=google_product&gl=us&google_domain=google.com&hl=en&product_id=9670509099135886512',
#   'source': 'McGrocer',
#   'price': '$63.74',
#   'extracted_price': 63.74,
#   'alternative_price': {'price': '£49.60',
#    'extracted_price': 49.6,
#    'currency': '£'},
#   'rating': 4.6,
#   'reviews': 6310,
#   'extensions': ['$0 minimum order'],
#   'thumbnail': 'https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcSCIl_O3XOdoujSLGMapCgWYaWN3YjfWb9t31sRyvI_1cqqGhyQLilZhJ0QFJrTuxQ9XYfij3JEYtP7bZR9weRMwg4RbT3Ihw&usqp=CAE',
#   'delivery': 'Delivery by Thu, Aug 29'},
#  {'position': 50,
#   'title': 'YSL Rouge Volupte Shine -Oil in a sticky Coral Dolman 12',
#   'link': 'https://www.whatnot.com/listing/TGlzdGluZ05vZGU6MjQwMzUxODgx',
#   'product_link': 'https://www.google.com/shopping/product/1?gl=us&prds=pid:17441779525690233888',
#   'product_id': '17441779525690233888',
#   'serpapi_product_api': 'https://serpapi.com/search.json?device=desktop&engine=google_product&gl=us&google_domain=google.com&hl=en&product_id=17441779525690233888',
#   'source': 'Whatnot',
#   'price': '$30.00',
#   'extracted_price': 30.0,
#   'rating': 4.6,
#   'reviews': 20710,
#   'thumbnail': 'https://encrypted-tbn1.gstatic.com/shopping?q=tbn:ANd9GcQiIot7MRLB7ejyjVL8oMlyAhutsJaJK_8Hz-SrcvLA5rO2jzM2p2rHI0kSmFt5PKCpV7MVSC_3CBJAUs2lPgsauMLMLfDsGrly-qnFo7Pqs0bmqBFTR5UB&usqp=CAE',
#   'delivery': 'Delivery by Mon, Aug 5'},
#  {'position': 51,
#   'title': 'YSL Yves Saint Laurent YSL Rouge Volupte Shine Lipstick - New Beauty | Color: Pink',
#   'link': 'https://www.mercari.com/us/item/m58793459990/?srsltid=AfmBOooMaH9VN6elVDbSK7Rl9CYLqf9-b9ADOZFUEI3EPVyVhPg0uEBdwII&com_cvv=d30042528f072ba8a22b19c81250437cd47a2f30330f0ed03551c4efdaf3409e',
#   'product_link': 'https://www.google.com/shopping/product/1?gl=us&prds=pid:14384181476105991321',
#   'product_id': '14384181476105991321',
#   'serpapi_product_api': 'https://serpapi.com/search.json?device=desktop&engine=google_product&gl=us&google_domain=google.com&hl=en&product_id=14384181476105991321',
#   'source': 'Mercari',
#   'price': '$21.00',
#   'extracted_price': 21.0,
#   'thumbnail': 'https://encrypted-tbn3.gstatic.com/shopping?q=tbn:ANd9GcS1qA0bjiBW8eurCW-124IUGmKahG8ojECWLNET5SHuBnoaxccb91tMkEkxtWkdZg7jboX8MQJNRFUOgqBrjjxuQRm_8pmS9SwjPhG9-bg&usqp=CAE',
#   'delivery': '$3.99 delivery'},
#  {'position': 52,
#   'title': 'Yves Saint Laurent Rouge Volupté Shine Lipstick Balm Color: 162 Pulsing Rosehip ...',
#   'link': 'https://maplefresh.ca/shop/makeup/lip/lipstick/yves-saint-laurent-rouge-volupte-shine-lipstick-balm-color-162-pulsing-rosehip-soft-rosy-nude/?srsltid=AfmBOooqUk_kct2DVKwyX19rJlwMfH7mxu-x0FaIbvrs2eYlUdhDKz4jT4Y&com_cvv=d30042528f072ba8a22b19c81250437cd47a2f30330f0ed03551c4efdaf3409e',
#   'product_link': 'https://www.google.com/shopping/product/1?gl=us&prds=pid:1686267764008762956',
#   'product_id': '1686267764008762956',
#   'serpapi_product_api': 'https://serpapi.com/search.json?device=desktop&engine=google_product&gl=us&google_domain=google.com&hl=en&product_id=1686267764008762956',
#   'source': 'Maplefresh',
#   'price': '$75.57',
#   'extracted_price': 75.57,
#   'old_price': '$100.76',
#   'extracted_old_price': 100.76,
#   'rating': 4.6,
#   'reviews': 5872,
#   'thumbnail': 'https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcTCwWKRejZhfGSvJYeNRo7lEVUiyks68F-1s1KjJ7dXLlKdlOuTo-OfM9ANvYMEd3i7zuJR6PRbc7KuAL5VuVegpbov1z3a5hIN0nKjaAVZDhpTfsbxnI4Akg&usqp=CAE',
#   'tag': 'SALE',
#   'extensions': ['SALE'],
#   'delivery': 'Free delivery by Wed, Aug 14'},
#  {'position': 53,
#   'title': 'Yves Saint Laurent Makeup | Yves Saint Laurent Rouge Volupte Shine Lip Colour ...',
#   'link': 'https://poshmark.com/listing/Yves-Saint-Laurent-Rouge-Volupte-Shine-Lip-Colour-5d4f34218ecb5d1a4aca00f6?srsltid=AfmBOormHbEOYqA7x2kwtiQMy25W2mfbrnfHD5KcDt-o7SqnEl4TdAMSn9c&com_cvv=d30042528f072ba8a22b19c81250437cd47a2f30330f0ed03551c4efdaf3409e#utm_source=gdm_unpaid',
#   'product_link': 'https://www.google.com/shopping/product/1?gl=us&prds=pid:10978476047756234809',
#   'product_id': '10978476047756234809',
#   'serpapi_product_api': 'https://serpapi.com/search.json?device=desktop&engine=google_product&gl=us&google_domain=google.com&hl=en&product_id=10978476047756234809',
#   'source': 'Poshmark',
#   'price': '$5.00',
#   'extracted_price': 5.0,
#   'old_price': '$8.00',
#   'extracted_old_price': 8.0,
#   'thumbnail': 'https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcTHpEy0f-pShpk4UWjRxupKRBPlnBfzPt-ov7lo1FhAD58yBnt_sVJJZ0Lp5sjWw6m8bemSWZ0O2bQ9vxURhtTl_Hhx0loHNyv8ZWc40h4&usqp=CAE',
#   'tag': 'SALE',
#   'extensions': ['SALE'],
#   'delivery': 'Delivery by Fri, Aug 9'},
#  {'position': 54,
#   'title': 'Bnib Ysl Rouge Volupte Shine Lipstick #124 Rose Loulou Full Size.',
#   'link': 'http://everymarket.com/products/bnib-ysl-rouge-volupte-shine-lipstick-124-rose-loulou-full-size?srsltid=AfmBOoqtS42wsqCxaMPobAdDdMmZRWNfDaufc8i9Cz21l5p42Up1xGiscM8&com_cvv=d30042528f072ba8a22b19c81250437cd47a2f30330f0ed03551c4efdaf3409e',
#   'product_link': 'https://www.google.com/shopping/product/1?gl=us&prds=pid:2975773273311161746',
#   'product_id': '2975773273311161746',
#   'serpapi_product_api': 'https://serpapi.com/search.json?device=desktop&engine=google_product&gl=us&google_domain=google.com&hl=en&product_id=2975773273311161746',
#   'source': 'EveryMarket',
#   'price': '$54.85',
#   'extracted_price': 54.85,
#   'rating': 4.6,
#   'reviews': 8107,
#   'thumbnail': 'https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcQANhNJL0gbjXzP8zrlztY_EU1OmzeSr83GjpTB-DIyjFrQccZOft726IHpwa8KQBIM4ehws0mVQgDC_-bMEGchZDpoAv_Jdx7EJJp56kt1Kn0ITOwNAJg5aw&usqp=CAE',
#   'delivery': 'Delivery by Thu, Aug 15'},
#  {'position': 55,
#   'title': 'YSL Rouge Volupte Rock N Shine Lipstick Rock’N Red',
#   'link': 'https://www.ebay.com/itm/353874921373?chn=ps&mkevt=1&mkcid=28&com_cvv=d30042528f072ba8a22b19c81250437cd47a2f30330f0ed03551c4efdaf3409e',
#   'product_link': 'https://www.google.com/shopping/product/1?gl=us&prds=pid:2264984413994203816',
#   'product_id': '2264984413994203816',
#   'serpapi_product_api': 'https://serpapi.com/search.json?device=desktop&engine=google_product&gl=us&google_domain=google.com&hl=en&product_id=2264984413994203816',
#   'source': 'eBay',
#   'price': '$50.00',
#   'extracted_price': 50.0,
#   'rating': 4.6,
#   'reviews': 201,
#   'thumbnail': 'https://encrypted-tbn3.gstatic.com/shopping?q=tbn:ANd9GcQ_lgudIvNRllJh8sh-ddnhCENdM3gDk58N4sn7eIk1Kk-wYCXscG1R5x0iKO4CDodC936rNHlWvSLpsXSfOhFM0DdVc869ypAGHtoWL5M&usqp=CAE',
#   'delivery': 'Delivery by Fri, Aug 9'},
#  {'position': 56,
#   'title': 'Yves Saint Laurent Lipstick - Pink',
#   'link': 'https://www.depop.com/products/leili24-yves-saint-laurent-color-162/?srsltid=AfmBOor4fVyHOcAY7USXGIEN764ABHMg8DCPfi9cDiTbl8ILIJVQsuFJcI8',
#   'product_link': 'https://www.google.com/shopping/product/1?gl=us&prds=pid:789126371700986651',
#   'product_id': '789126371700986651',
#   'serpapi_product_api': 'https://serpapi.com/search.json?device=desktop&engine=google_product&gl=us&google_domain=google.com&hl=en&product_id=789126371700986651',
#   'source': 'Depop',
#   'price': '$40.50',
#   'extracted_price': 40.5,
#   'old_price': '$45.00',
#   'extracted_old_price': 45.0,
#   'thumbnail': 'https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9G
product_link': 'https://www.google.com/shopping/product/1?gl=us&prds=pid:16215417500206166357',
#   'product_id': '16215417500206166357',
#   'serpapi_product_api': 'https://serpapi.com/search.json?device=desktop&engine=google_product&gl=us&google_domain=google.com&hl=en&product_id=16215417500206166357',
#   'source': 'Maplefresh',
#   'price': '$75.57',
#   'extracted_price': 75.57,
#   'old_price': '$100.76',
#   'extracted_old_price': 100.76,
#   'rating': 4.6,
#   'reviews': 8107,
#   'thumbnail': 'https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcR3RdMsqxKaLFmqOo2n7sAVtCT7FraOE8vrBxPpqTutexCo8aq393fkHMoO_ab5uLs9pGoOJJLjxNNesKxag5BOg7DqJ3b4cfjuhS7uqkeYTUnh4STB6K_H4w&usqp=CAE',
#   'tag': 'SALE',
#   'extensions': ['SALE'],
#   'delivery': 'Free delivery by Wed, Aug 14'}]

# %% [markdown]
# Sephora api key

# %%
2896fc08-3252-49c0-94a4-7e9f9bf85663

# %%
import requests

url = "https://sephora.p.rapidapi.com/us/products/v2/search"

querystring = {"pageSize":"60","currentPage":"1","q":"#161112 foundation","sortBy":"P_BEST_SELLING"}

headers = {
	"x-rapidapi-key": "2feb5257eemsh93c5c510406ef6dp102d41jsncb609158bbf1",
	"x-rapidapi-host": "sephora.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'categories': [{'displayName': 'Makeup', 'level': '0', 'nodeStr': 'cat140006', 'recordCount': '15'}, {'displayName': 'Gifts', 'level': '0', 'nodeStr': 'cat60270', 'recordCount': '6'}, {'displayName': 'Clean at Sephora', 'level': '0', 'nodeStr': 'cat3780034', 'recordCount': '2'}, {'displayName': 'Fragrance', 'level': '0', 'nodeStr': 'cat160006', 'recordCount': '3'}, {'displayName': 'Tools & Brushes', 'level': '0', 'nodeStr': 'cat130042', 'recordCount': '1'}, {'displayName': 'Hair', 'level': '0', 'nodeStr': 'cat130038', 'recordCount': '1'}], 'features': {'a_a_test': False, 'auto_generated_refined_query_rules': True, 'custom_autosuggest_ui': False, 'disable_test_only_global_rules_browse': False, 'disable_test_only_global_rules_search': False, 'filter_items': True, 'manual_searchandizing': True, 'personalization': True, 'query_items': True, 'use_enriched_attributes_as_fuzzy_searchable': False, 'use_reranker_service_for_all': False, 'use_reranker_service_for_browse': True, 'use_reranker_service_for_search': True}, 'keyword': '#161112 foundation', 'products': [{'brandName': 'HAUS LABS BY LADY GAGA', 'currentSku': {'imageAltText': 'HAUS LABS BY LADY GAGA - Triclone Skin Tech Medium Coverage Foundation with Fermented Arnica', 'isAppExclusive': False, 'isBI': False, 'isBest': False, 'isFirstAccess': False, 'isLimitedEdition': False, 'isLimitedTimeOffer': False, 'isNatural': False, 'isNew': False, 'isOnlineOnly': False, 'isOrganic': False, 'isSephoraExclusive': True, 'listPrice': '$45.00', 'skuId': '2597276', 'skuType': 'Standard'}, 'displayName': 'Triclone Skin Tech Medium Coverage Foundation with Fermented Arnica', 'heroImage': 'https://www.sephora.com/productimages/sku/s2597276-main-zoom.jpg?imwidth=270&pb=allure-2023-clean-badge', 'image135': 'https://www.sephora.com/productimages/sku/s2597276-main-zoom.jpg?imwidth=270&pb=allure-2023-clean-badge', 'image250': 'https://www.sephora.com/productimages/sku/s2597276-main-zoom.jpg?imwidth=270&pb=allure-2023-clean-badge', 'image450': 'https://www.sephora.com/productimages/sku/s2597276-main-zoom.jpg?imwidth=270&pb=allure-2023-clean-badge', 'altImage': 'https://www.sephora.com/productimages/sku/s2597276-av-16-zoom.jpg?imwidth=270', 'moreColors': 50, 'onSaleData': 'NONE', 'pickupEligible': False, 'productId': 'P502185', 'productName': 'Triclone Skin Tech Medium Coverage Foundation with Fermented Arnica', 'rating': '4.1074', 'reviews': '3268', 'sameDayEligible': False, 'shipToHomeEligible': False, 'targetUrl': '/product/triclone-skin-tech-medium-coverage-foundation-with-fermented-arnica-P502185?skuId=2597276', 'sponsored': False}, {'brandName': 'Fenty Beauty by Rihanna', 'currentSku': {'imageAltText': 'Fenty Beauty by Rihanna - Pro Filt’r Soft Matte Longwear Liquid Foundation', 'isAppExclusive': False, 'isBI': False, 'isBest': False, 'isFirstAccess': False, 'isLimitedEdition': False, 'isLimitedTimeOffer': False, 'isNatural': False, 'isNew': False, 'isOnlineOnly': False, 'isOrganic': False, 'isSephoraExclusive': False, 'listPrice': '$18.00 - $40.00', 'skuId': '2590032', 'skuType': 'Standard'}, 'displayName': 'Pro Filt’r Soft Matte Longwear Liquid Foundation', 'heroImage': 'https://www.sephora.com/productimages/sku/s2590032-main-zoom.jpg?imwidth=270', 'image135': 'https://www.sephora.com/productimages/sku/s2590032-main-zoom.jpg?imwidth=270', 'image250': 'https://www.sephora.com/productimages/sku/s2590032-main-zoom.jpg?imwidth=270', 'image450': 'https://www.sephora.com/productimages/sku/s2590032-main-zoom.jpg?imwidth=270', 'altImage': 'https://www.sephora.com/productimages/sku/s2590032-av-2-zoom.jpg?imwidth=270', 'moreColors': 50, 'onSaleData': 'NONE', 'pickupEligible': False, 'productId': 'P87985432', 'productName': 'Pro Filt’r Soft Matte Longwear Liquid Foundation', 'rating': '4.0188', 'reviews': '17395', 'sameDayEligible': False, 'shipToHomeEligible': False, 'targetUrl': '/product/pro-filtr-soft-matte-longwear-foundation-P87985432?skuId=2590032', 'sponsored': False}, {'brandName': 'Armani Beau ...

# %%
import json

# Assuming 'data' is the JSON object containing the product information
# For example: data = json.loads(your_json_string)

def extract_product_info(data):
    extracted_info = []
    
    for product in data.get("products", []):
        product_info = {
            "displayName": product.get("displayName"),
            "heroImage": product.get("heroImage"),
            "price": product.get("price"),
            "productId": product.get("productId"),
            "reviews": product.get("reviews"),
            "rating": product.get("rating"),
            "onSaleData": product.get("onSaleData"),
            "isLimitedTimeOffer": product.get("isLimitedTimeOffer")
        }
        extracted_info.append(product_info)
    
    return extracted_info

# Example usage:
# result = extract_product_info(data)
extract_product_info(response.json())
# Out:
# [{'displayName': 'Triclone Skin Tech Medium Coverage Foundation with Fermented Arnica',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2597276-main-zoom.jpg?imwidth=270&pb=allure-2023-clean-badge',
#   'price': None,
#   'productId': 'P502185',
#   'reviews': '3268',
#   'rating': '4.1074',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Pro Filt’r Soft Matte Longwear Liquid Foundation',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2590032-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P87985432',
#   'reviews': '17395',
#   'rating': '4.0188',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Luminous Silk Perfect Glow Flawless Oil-Free Foundation',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s1359686-main-zoom.jpg?imwidth=270&pb=2020-03-allure-best-2019',
#   'price': None,
#   'productId': 'P393401',
#   'reviews': '4635',
#   'rating': '4.2093',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Double Wear Stay-in-Place Foundation',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2602043-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P378284',
#   'reviews': '7462',
#   'rating': '4.3668',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Natural Radiant Longwear Foundation',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2031011-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P427301',
#   'reviews': '3980',
#   'rating': '3.6628',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Hollywood Flawless Filter',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2419786-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P434104',
#   'reviews': '3099',
#   'rating': '4.2753',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Born This Way Natural Finish Longwear Liquid Foundation',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2084648-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P397517',
#   'reviews': '15030',
#   'rating': '4.0407',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Dior Forever Skin Glow Foundation SPF 15',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2508869-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P439941',
#   'reviews': '1119',
#   'rating': '4.2377',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Liquid Touch Weightless Foundation',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2361608-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P49848448',
#   'reviews': '5684',
#   'rating': '3.9699',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Soft’Lit Naturally Luminous Hydrating Longwear Foundation',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2746543-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P511130',
#   'reviews': '374',
#   'rating': '4.3877',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Softlight Skin-Smoothing Hydrating Non-Comedogenic Foundation',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2698108-main-zoom.jpg?imwidth=270&pb=clean-planet-aware',
#   'price': None,
#   'productId': 'P507996',
#   'reviews': '542',
#   'rating': '4.6845',
#   'onSaleData': 'FULL',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'CHANCE EAU TENDRE Eau de Toilette',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s1237379-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P258612',
#   'reviews': '654',
#   'rating': '4.6483',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Good Girl Blush Eau de Parfum',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2645026-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P504996',
#   'reviews': '647',
#   'rating': '4.2921',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': '24 Hour Full Coverage Luminous Matte Finish Foundation',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2666691-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P467622',
#   'reviews': '846',
#   'rating': '4.3712',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Bow Snap Hair Clips',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2800894-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P512276',
#   'reviews': '25',
#   'rating': '5.0',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'Terracotta Le Teint Healthy Glow Foundation',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2663805-main-zoom.jpg?imwidth=270&pb=allure-2023-bestofbeauty-badge',
#   'price': None,
#   'productId': 'P505377',
#   'reviews': '217',
#   'rating': '4.235',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'The Soft Fluid Long Wear Foundation SPF 20',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s1999895-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P423742',
#   'reviews': '400',
#   'rating': '4.045',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'The Luminous Lifting Cushion Foundation SPF 20 + Refill',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2132231-main-zoom.jpg?imwidth=270',
#   'price': None,
#   'productId': 'P437500',
#   'reviews': '85',
#   'rating': '4.0824',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None},
#  {'displayName': 'H2Eau - Brilliant Peony Eau de Parfum',
#   'heroImage': 'https://www.sephora.com/productimages/sku/s2635977-main-zoom.jpg?imwidth=270&pb=clean-at-sephora',
#   'price': None,
#   'productId': 'P508146',
#   'reviews': '64',
#   'rating': '4.3438',
#   'onSaleData': 'NONE',
#   'isLimitedTimeOffer': None}]

# %%
curl --location --request GET 'https://app.retailed.io/api/v1/scra
# Out:
#   Cell In[3], line 1
#     curl --location --request GET 'https://app.retailed.io/api/v1/scra
#                                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
curl --location --request GET 'https://app.retailed.io/api/v1/scraper/sephora/product?productId=12345' --header 'Content-Type: application/json' --header '2896fc08-3252-49c0-94a4-7e9f9bf85663'
# Out:
#   Cell In[8], line 1
#     curl --location --request GET 'https://app.retailed.io/api/v1/scraper/sephora/product?productId=12345' --header 'Content-Type: application/json' --header '2896fc08-3252-49c0-94a4-7e9f9bf85663'
#                               ^
# SyntaxError: invalid syntax
